# %%
# !pip install PyWavelets

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/39.5 MB 2.8 MB/s eta 0:00:14
#    ---------------------------------------- 0.4/39.5 MB 3.9 MB/s eta 0:00:11
#    ---------------------------------------- 0.4/39.5 MB 3.9 MB/s eta 0:00:11
#     --------------------------------------- 0.6/39.5 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.8/39.5 MB 3.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.1/39.5 MB 4.5 MB/s eta 0:00:09
#    - -------------------------------------- 1.4/39.5 MB 4.7 MB/s eta 0:00:09
#    - -------------------------------------- 1.8/39.5 MB 5.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/39.5 MB 5.2 MB/s eta 0:00:08
#    -- ------------------------------------- 2.3/39.5 MB 5.4 MB/s eta 0:00:07
# ...

# %%
# !pip install seaborn

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
img = cv2.imread("./TestImages/testmessi.jpeg")
img.shape
# Out:
# (275, 183, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (275, 183)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[42, 54, 92, 92]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (42, 54, 92, 92)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
eyes = eye_cascade.detectMultiScale(gray,scaleFactor=1.1)
eyes
# Out:
# array([[90, 78, 25, 25],
#        [58, 79, 23, 23]])

# %%
for (ex, ey, ew, eh) in eyes:
    eyes_img = cv2.rectangle(img, (ex, ey), (ex + ew, ey + eh), (0, 255, 0), 2)
    
plt.imshow(eyes_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(face_img,scaleFactor=1.1)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(face_img,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(gray, scaleFactor=1.1)
    print(f"eyes detected: {len(eyes)}")
    if len(eyes) == 2:  # Solo dibujar si detectó ambos ojos
        for (ex, ey, ew, eh) in eyes:
            cv2.rectangle(gray, (ex, ey), (ex+ew, ey+eh), (0, 255, 0), 2)
    else:
        print("both eyes not detected correctly")

        
plt.figure()
plt.imshow(face_img) 
plt.show()
# Out:
# eyes detected: 2

# %%
img2 = cv2.imread("./TestImages/testmessi3.jpeg")
plt.imshow(img2)

# %%
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
plt.imshow(gray2, cmap='gray')

# %%
face2 = face_cascade.detectMultiScale(gray2, 1.3, 5)
(x,y,w,h) = face2[0]
x,y,w,h
face_img2 = cv2.rectangle(img2,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img2)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(gray)
        if len(eyes) >= 2:
            return roi_color
        else:
            print('Both eyes not detected correctly')

# %%
original_img = cv2.imread("./TestImages/testmessi3.jpeg")
cropped_image = get_cropped_image_if_2_eyes('./TestImages/testmessi3.jpeg')
plt.imshow(cropped_image)

# %%
not_eough_eyes = cv2.imread("./TestImages/testmessi.jpeg")
cropped_image = get_cropped_image_if_2_eyes('./TestImages/testmessi.jpeg')
plt.imshow(cropped_image)

# %%
path_to_data = "./data/"
path_to_cr_data = "./data/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./data/Cristiano Ronaldo',
#  './data/cropped',
#  './data/Erling Haaland',
#  './data/Jude Bellingham',
#  './data/Kylian Mbappe',
#  './data/Leonel Messi']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}

for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Cristiano Ronaldo
# Both eyes not detected correctly
# Both eyes not detected correctly
# Generating cropped images in folder:  ./data/cropped/Cristiano Ronaldo
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# Both eyes not detected correctly
# cropped
# ---------------------------------------------------------------------------
# ...
