# %%
# !pip install PyWavelets

# %%
# !pip install opencv-python
# Out:
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/39.5 MB 2.8 MB/s eta 0:00:14
#    ---------------------------------------- 0.4/39.5 MB 3.9 MB/s eta 0:00:11
#    ---------------------------------------- 0.4/39.5 MB 3.9 MB/s eta 0:00:11
#     --------------------------------------- 0.6/39.5 MB 3.7 MB/s eta 0:00:11
#     --------------------------------------- 0.8/39.5 MB 3.9 MB/s eta 0:00:10
#    - -------------------------------------- 1.1/39.5 MB 4.5 MB/s eta 0:00:09
#    - -------------------------------------- 1.4/39.5 MB 4.7 MB/s eta 0:00:09
#    - -------------------------------------- 1.8/39.5 MB 5.2 MB/s eta 0:00:08
#    - -------------------------------------- 1.8/39.5 MB 5.2 MB/s eta 0:00:08
#    -- ------------------------------------- 2.3/39.5 MB 5.4 MB/s eta 0:00:07
# ...

# %%
# !pip install seaborn

# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt

# %%
from PIL import Image
img = Image.open("./testImages/Testmessi.jpg")
img.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 from PIL import Image
# ----> 2 img = Image.open("./testImages/Testmessi.jpg")
#       3 img.show()
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3247, in open(fp, mode, formats)
#    3244     filename = fp
#    3246 if filename:
# -> 3247     fp = builtins.open(filename, "rb")
#    3248     exclusive_fp = True
#    3250 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: './testImages/Testmessi.jpg'

# %%
import os

ruta = "./testImages/Testmessi.jpg"
print("¿El archivo existe?", os.path.exists(ruta))
# Out:
# ¿El archivo existe? False
